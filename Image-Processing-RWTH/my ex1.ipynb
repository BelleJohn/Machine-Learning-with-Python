# %%
# The matplotlib magic function and library imports
# %matplotlib inline
import cv2
import matplotlib.image as mpimg
import numpy as np
from matplotlib import pyplot as plt

img = mpimg.imread('castle.jpg')
plt.imshow(img)

# %%
# matrix exercise
A = np.array([
    [4, -1],
    [2, 3]
])
B = np.array([
    [5, 3],
    [0, 1]
])
C = np.array([
    [9, 8],
    [-6, 2]
])
D = (A.dot(B)).dot(C)
E=A.dot(B) # A*B
E
# Out:
# array([[20, 11],
#        [10,  9]])

# %%
li = ["abc", 2.71, 42] #if not add this before, computer will add new data on the result that ran last time 
li[1]
li.append('newelement')
li.insert(2, 653)
li.extend([99,100,101])
li
# Out:
# ['abc', 2.71, 653, 42, 'newelement', 99, 100, 101]

# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Create image: it contains only white pixels
height, width = 400, 200
img = np.zeros((height,width,3), np.uint8)

# Output the image dimensions
#print(len(img), len(img[0]), len(img[0][0]))

# Output empty image data as a multidimensional array of RGB pixels
#print(img)

# Fill image with a red and a green bar
#img[:, 0 : int(0.5 * width)] = (255,0,0)
#img[:, int(0.5*width) : width] = (0,255,0)

plt.imshow(img) #print(img) only show numbers
#plt.title('New Image: Half Red, Half Green'), plt.xticks([]), plt.yticks([]);

# %%
###TASK 1
# The matplotlib magic function and library imports
# %matplotlib inline
import cv2
import matplotlib.image as mpimg
import numpy as np
from matplotlib import pyplot as plt

img = mpimg.imread('castle.jpg')
pylab.rcParams["figure.figsize"] = (20,15)

# Start typing your code here.

img_cropped = img[1000:3500,1000:2500]
img_flipped = cv2.flip(img_cropped,1) # 0=original 1=the other side

# End of your code

# Output the original image, and its cropped and flipped variants
plt.subplot(311)
plt.imshow(img)
plt.subplot(312)
plt.imshow(img_cropped)
plt.subplot(313)
plt.imshow(img_flipped)

# %%
###TASK 2
# The matplotlib magic function and library imports
# %matplotlib inline
import cv2
import matplotlib.image as mpimg
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from PIL import ImageEnhance

img = mpimg.imread('mammogram1.png')
plt.rcParams["figure.figsize"] = (20,15)
#cimg = np.int16(img)  
# Start typing your code here.


# img_brightness = ...
#enhancer = ImageEnhance.Brightness(img)
enhancer = ImageEnhance(img)
brightness = 1.8
img_brightness = enhancer.enhance(brightness)


#img_contrast = 


# End of your code

# Output the original and brightness- and contrast-adjusted images
plt.subplot(311)
plt.imshow(img)
plt.subplot(312)
plt.imshow(img_brightness)
#plt.subplot(313)
#plt.imshow(img_contrast)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bbb474e0ac55> in <module>()
#      17 # img_brightness = ...
#      18 #enhancer = ImageEnhance.Brightness(img)
# ---> 19 enhancer = ImageEnhance(img)
#      20 brightness = 1.8
#      21 img_brightness = enhancer.enhance(brightness)
#
# TypeError: 'module' object is not callable

# %%
###TASK 2
# %matplotlib inline
import cv2
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pylab as pylab
from matplotlib import pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)
img = cv2.imread('mammogram1.png',0)

# Convert to signed 16-bit integer to allow values outside of the (0,255) range
cimg = np.int16(img)  

# YOUR CODE HERE
gain = 1.5 #contrast
bias = -80 #-10 brighter -1000 darker

cimg = img*gain + bias
cimg = np.clip(cimg,0, 255)
# END OF YOUR CODE

# Convert back to uint8 values
cimg = np.uint8(cimg)

plt.subplot(121), plt.imshow(img, cmap = 'gray')
plt.title('Original mammogram'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(cimg, cmap = 'gray')
plt.title('Brightness-adjusted mammogram'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
###TASK 3
##Reference https://www.jianshu.com/p/b5c29aeaedc7
# %matplotlib inline
import cv2
import matplotlib.image as mpimg
import numpy as np
from matplotlib import pyplot as plt

img = mpimg.imread('castle.jpg')
rows, cols, depth = img.shape

# Start typing your code here

def rotate(image, angle, center=None, scale=1.0):
    # obtain image scale
    (h, w) = image.shape[:2]
 
    # If not assign ceter position, then set center at (w / 2, h / 2)
    if center is None:
        center = (w / 2, h / 2)
 
    # conduct rotation
    M = cv2.getRotationMatrix2D(center, angle, scale)
    rotated = cv2.warpAffine(image, M, (w, h))
 
    # return image
    return rotated

rotated = rotate(img, -90)


# End of your code
plt.rcParams["figure.figsize"] = (15, 20)
imgplotst = plt.imshow(rotated)
